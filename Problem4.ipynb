# %% [markdown]
# ## Problem 4
#
# In this exercise, we want to compare interpolation methods. For this reason, import the scipy library as ``sp`` and the matplotlib.pyplot as ``plt``.
#
# a) We want to approximate the sine function on $[0, 2\pi]$ with finitely many points. For this reason, use ``np.linspace(x, y, n)`` to create a list of equidistant evaluation points ``xgrid``. Choose ``n=10``.
#
# **Example:**
#
# The command ``np.linspace(x, y, n)`` creates an array of ``n`` evenly spaced points between ``x`` and ``y``. You can compute the sine of these points using ``np.sin()``.

# %%
import numpy as np

a = np.pi # start at pi
b = 15
n = 5
grid = np.linspace(a, b, n)
print(grid)
# Out:
# [ 3.14159265  6.10619449  9.07079633 12.03539816 15.        ]

# %%
# ... your code

# %% [markdown]
# b) Generate a list of function values ``ypts`` using ``np.sin()``.

# %%
# ...

# %% [markdown]
# c) Create a list of query points ``xp`` over $[0,2\pi]$. Use ``n=100``.

# %%
# ...

# %% [markdown]
# d) Generate an interpolated function ``xp_lin`` by using ``sp.interpolate.interp1d(x, y, 'linear')`` and evaluate this function atyour list of query points. Call this list ``yp_lin``.
#
# **Example:**

# %%
import scipy as sp

x_example = np.linspace(-2, 2, 10)
y_example = x_example**2 - 2

# construct interpolation function f
f = sp.interpolate.interp1d(x_example, y_example, 'linear')

# evaluate f at some points
x_eval = np.linspace(-2, 2, 15)
y_eval = f(x_eval)
print(y_eval)
# Out:
# [ 2.          0.98412698  0.08112875 -0.68077601 -1.21693122 -1.64021164
#  -1.89417989 -1.95061728 -1.89417989 -1.64021164 -1.21693122 -0.68077601
#   0.08112875  0.98412698  2.        ]

# %%
# ... your code

# %% [markdown]
# e) Do the exact same step but replace ``linear`` by ``cubic`` and save the resulting list as ``yp_cub``.

# %%
# ...

# %% [markdown]
# f) Now, we want to visualize the differences in these interpolation methods. First, we set up a figure with command ``fig, ax = plt.subplots(figsize=(10, 6))``. The command ``ax.plot(x1, y1,...)`` generates a plot and ``plt.show()`` displays the plot in a new window.
#
# **Example:**

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(x_example, y_example, color='blue')
plt.show()

# %%
# ... your code

# %% [markdown]
# g) Start again at a), but this time choose n=50. Do tasks b) - f) as before.

# %%
# ...

# %% [markdown]
# h) Evaluate the approximations: Draw a set of random numbers. Use e.g. ``rand`` from NumPy's sublibrary ``random`` to draw uniformly distributed values in $(0,1)$, and transform them accordingly. For each random point in $[0, 2\pi]$, compute the actual function value and evaluate the approximations. Finally, compute both the average and maximum errors.
#
# **Example:**

# %%
u = np.random.rand(10) # draw some random numbers
avg_u = np.mean(u) # compute the mean

print(u)
print(avg_u)
# Out:
# [0.63563442 0.42175115 0.52139197 0.81498144 0.10658874 0.24706976
#  0.48519022 0.90795447 0.83752828 0.60826521]
# 0.5586355669038546

# %%
# ... your code
