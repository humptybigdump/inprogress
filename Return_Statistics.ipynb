# %% [markdown]
# # Goal: Running a Basic Explorative Asset Return Analysis

# %% [markdown]
# ## Hey, Python techies!!

# %% [markdown]
# The first step when working with a financial data set is often to calculate some basic return statistics. For that, we plot the time series of asset returns, calculate its annualized mean and volatility and compute its Sharpe ratio. This way, we get a feeling for the data and are able to immediately identify strange-looking numbers, which would likely point to errors in the data set.
#
# ## Let's see how all of that works.

# %% [markdown]
# For the analysis, we will need the pandas, the numpy and the matplotlib modules, which we import first.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2024-11-09 15:43:59.083 system_profiler[20512:539499] CoreText note: Client requested name ".AlBayanPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.083 system_profiler[20512:539499] CoreText note: Set a breakpoint on CTFontLogSystemFontNameRequest to debug.
# 2024-11-09 15:43:59.087 system_profiler[20512:539499] CoreText note: Client requested name ".AlBayanPUA-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.092 system_profiler[20512:539499] CoreText note: Client requested name ".AlNilePUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.094 system_profiler[20512:539499] CoreText note: Client requested name ".AlNilePUA-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.100 system_profiler[20512:539499] CoreText note: Client requested name ".AlTarikhPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.103 system_profiler[20512:539499] CoreText note: Client requested name ".AppleColorEmojiUI", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.105 system_profiler[20512:539499] CoreText note: Client requested name ".AppleSDGothicNeoI-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.108 system_profiler[20512:539499] CoreText note: Client requested name ".AppleSDGothicNeoI-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.110 system_profiler[20512:539499] CoreText note: Client requested name ".AppleSDGothicNeoI-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.113 system_profiler[20512:539499] CoreText note: Client requested name ".AppleSDGothicNeoI-UltraLight", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.115 system_profiler[20512:539499] CoreText note: Client requested name ".AppleSDGothicNeoI-Thin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.118 system_profiler[20512:539499] CoreText note: Client requested name ".AppleSDGothicNeoI-SemiBold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.121 system_profiler[20512:539499] CoreText note: Client requested name ".AppleSDGothicNeoI-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.123 system_profiler[20512:539499] CoreText note: Client requested name ".AppleSDGothicNeoI-ExtraBold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.125 system_profiler[20512:539499] CoreText note: Client requested name ".AppleSDGothicNeoI-Heavy", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.147 system_profiler[20512:539499] CoreText note: Client requested name ".ArabicUIDisplay-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.151 system_profiler[20512:539499] CoreText note: Client requested name ".ArabicUIDisplay-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.153 system_profiler[20512:539499] CoreText note: Client requested name ".ArabicUIDisplay-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.156 system_profiler[20512:539499] CoreText note: Client requested name ".ArabicUIDisplay-Thin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.158 system_profiler[20512:539499] CoreText note: Client requested name ".ArabicUIDisplay-Ultralight", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.161 system_profiler[20512:539499] CoreText note: Client requested name ".ArabicUIDisplay-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.163 system_profiler[20512:539499] CoreText note: Client requested name ".ArabicUIDisplay-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.166 system_profiler[20512:539499] CoreText note: Client requested name ".ArabicUIDisplay-Heavy", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.168 system_profiler[20512:539499] CoreText note: Client requested name ".ArabicUIDisplay-Black", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.172 system_profiler[20512:539499] CoreText note: Client requested name ".ArabicUIText-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.174 system_profiler[20512:539499] CoreText note: Client requested name ".ArabicUIText-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.177 system_profiler[20512:539499] CoreText note: Client requested name ".ArabicUIText-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.180 system_profiler[20512:539499] CoreText note: Client requested name ".ArabicUIText-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.182 system_profiler[20512:539499] CoreText note: Client requested name ".ArabicUIText-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.185 system_profiler[20512:539499] CoreText note: Client requested name ".ArabicUIText-Heavy", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.188 system_profiler[20512:539499] CoreText note: Client requested name ".ArialHebrewDeskInterface", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.190 system_profiler[20512:539499] CoreText note: Client requested name ".ArialHebrewDeskInterface-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.192 system_profiler[20512:539499] CoreText note: Client requested name ".ArialHebrewDeskInterface-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.196 system_profiler[20512:539499] CoreText note: Client requested name ".BaghdadPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.199 system_profiler[20512:539499] CoreText note: Client requested name ".BeirutPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.201 system_profiler[20512:539499] CoreText note: Client requested name ".DamascusPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.203 system_profiler[20512:539499] CoreText note: Client requested name ".DamascusPUAMedium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.205 system_profiler[20512:539499] CoreText note: Client requested name ".DamascusPUALight", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.208 system_profiler[20512:539499] CoreText note: Client requested name ".DamascusPUASemiBold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.210 system_profiler[20512:539499] CoreText note: Client requested name ".DamascusPUABold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.212 system_profiler[20512:539499] CoreText note: Client requested name ".DecoTypeNaskhPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.216 system_profiler[20512:539499] CoreText note: Client requested name ".DiwanKufiPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.218 system_profiler[20512:539499] CoreText note: Client requested name ".FarahPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.220 system_profiler[20512:539499] CoreText note: Client requested name ".GeezaProInterface", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.223 system_profiler[20512:539499] CoreText note: Client requested name ".GeezaProInterface-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.225 system_profiler[20512:539499] CoreText note: Client requested name ".GeezaProInterface-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.227 system_profiler[20512:539499] CoreText note: Client requested name ".GeezaProPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.230 system_profiler[20512:539499] CoreText note: Client requested name ".GeezaProPUA-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.244 system_profiler[20512:539499] CoreText note: Client requested name ".HelveticaNeueDeskInterface-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.249 system_profiler[20512:539499] CoreText note: Client requested name ".HelveticaNeueDeskInterface-MediumP4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.253 system_profiler[20512:539499] CoreText note: Client requested name ".HelveticaNeueDeskInterface-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.257 system_profiler[20512:539499] CoreText note: Client requested name ".HelveticaNeueDeskInterface-Thin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.260 system_profiler[20512:539499] CoreText note: Client requested name ".HelveticaNeueDeskInterface-UltraLightP2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.265 system_profiler[20512:539499] CoreText note: Client requested name ".HelveticaNeueDeskInterface-Italic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.268 system_profiler[20512:539499] CoreText note: Client requested name ".HelveticaNeueDeskInterface-MediumItalicP4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.272 system_profiler[20512:539499] CoreText note: Client requested name ".HelveticaNeueDeskInterface-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.275 system_profiler[20512:539499] CoreText note: Client requested name ".HelveticaNeueDeskInterface-Heavy", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.279 system_profiler[20512:539499] CoreText note: Client requested name ".HelveticaNeueDeskInterface-BoldItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.281 system_profiler[20512:539499] CoreText note: Client requested name ".HiraKakuInterface-W3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.285 system_profiler[20512:539499] CoreText note: Client requested name ".HiraKakuInterface-W4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.288 system_profiler[20512:539499] CoreText note: Client requested name ".HiraKakuInterface-W2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.292 system_profiler[20512:539499] CoreText note: Client requested name ".HiraKakuInterface-W1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.295 system_profiler[20512:539499] CoreText note: Client requested name ".HiraKakuInterface-W0", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.298 system_profiler[20512:539499] CoreText note: Client requested name ".HiraKakuInterface-W5", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.302 system_profiler[20512:539499] CoreText note: Client requested name ".HiraKakuInterface-W6", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.305 system_profiler[20512:539499] CoreText note: Client requested name ".HiraKakuInterface-W7", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.308 system_profiler[20512:539499] CoreText note: Client requested name ".HiraKakuInterface-W8", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.311 system_profiler[20512:539499] CoreText note: Client requested name ".HiraKakuInterface-W9", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.315 system_profiler[20512:539499] CoreText note: Client requested name ".HiraginoSansGBInterface-W3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.318 system_profiler[20512:539499] CoreText note: Client requested name ".HiraginoSansGBInterface-W6", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.322 system_profiler[20512:539499] CoreText note: Client requested name ".Keyboard", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.325 system_profiler[20512:539499] CoreText note: Client requested name ".KufiStandardGKPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.331 system_profiler[20512:539499] CoreText note: Client requested name ".LucidaGrandeUI", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.337 system_profiler[20512:539499] CoreText note: Client requested name ".LucidaGrandeUI-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.340 system_profiler[20512:539499] CoreText note: Client requested name ".MunaPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.343 system_profiler[20512:539499] CoreText note: Client requested name ".MunaPUABold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.345 system_profiler[20512:539499] CoreText note: Client requested name ".MunaPUABlack", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.349 system_profiler[20512:539499] CoreText note: Client requested name ".NadeemPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.355 system_profiler[20512:539499] CoreText note: Client requested name ".NewYork-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.358 system_profiler[20512:539499] CoreText note: Client requested name ".NewYork-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.363 system_profiler[20512:539499] CoreText note: Client requested name ".NewYork-RegularItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.367 system_profiler[20512:539499] CoreText note: Client requested name ".NewYork-MediumItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.370 system_profiler[20512:539499] CoreText note: Client requested name ".NewYork-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.373 system_profiler[20512:539499] CoreText note: Client requested name ".NewYork-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.376 system_profiler[20512:539499] CoreText note: Client requested name ".NewYork-Heavy", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.379 system_profiler[20512:539499] CoreText note: Client requested name ".NewYork-Black", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.382 system_profiler[20512:539499] CoreText note: Client requested name ".NewYork-SemiboldItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.385 system_profiler[20512:539499] CoreText note: Client requested name ".NewYork-BoldItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.388 system_profiler[20512:539499] CoreText note: Client requested name ".NewYork-HeavyItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.391 system_profiler[20512:539499] CoreText note: Client requested name ".NewYork-BlackItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.393 system_profiler[20512:539499] CoreText note: Client requested name ".NotoNastaliqUrduUI", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.396 system_profiler[20512:539499] CoreText note: Client requested name ".NotoNastaliqUrduUI-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.400 system_profiler[20512:539499] CoreText note: Client requested name ".PingFangHK-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.404 system_profiler[20512:539499] CoreText note: Client requested name ".PingFangHK-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.408 system_profiler[20512:539499] CoreText note: Client requested name ".PingFangHK-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.411 system_profiler[20512:539499] CoreText note: Client requested name ".PingFangHK-Thin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.414 system_profiler[20512:539499] CoreText note: Client requested name ".PingFangHK-Ultralight", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.418 system_profiler[20512:539499] CoreText note: Client requested name ".PingFangHK-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.421 system_profiler[20512:539499] CoreText note: Client requested name ".PingFangSC-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.423 system_profiler[20512:539499] CoreText note: Client requested name ".PingFangSC-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.426 system_profiler[20512:539499] CoreText note: Client requested name ".PingFangSC-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.428 system_profiler[20512:539499] CoreText note: Client requested name ".PingFangSC-Thin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.432 system_profiler[20512:539499] CoreText note: Client requested name ".PingFangSC-Ultralight", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.435 system_profiler[20512:539499] CoreText note: Client requested name ".PingFangSC-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.438 system_profiler[20512:539499] CoreText note: Client requested name ".PingFangTC-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.440 system_profiler[20512:539499] CoreText note: Client requested name ".PingFangTC-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.443 system_profiler[20512:539499] CoreText note: Client requested name ".PingFangTC-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.445 system_profiler[20512:539499] CoreText note: Client requested name ".PingFangTC-Thin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.449 system_profiler[20512:539499] CoreText note: Client requested name ".PingFangTC-Ultralight", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.452 system_profiler[20512:539499] CoreText note: Client requested name ".PingFangTC-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.454 system_profiler[20512:539499] CoreText note: Client requested name ".SanaPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.457 system_profiler[20512:539499] CoreText note: Client requested name ".SavoyeLetPlainCC", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.461 system_profiler[20512:539499] CoreText note: Client requested name "..SFCompactDisplay-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.465 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactDisplay-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.469 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactDisplay-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.472 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactDisplay-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.474 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactDisplay-Thin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.477 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactDisplay-Ultralight", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.481 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactDisplay-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.484 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactDisplay-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.487 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactDisplay-Heavy", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.491 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactDisplay-Black", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.496 system_profiler[20512:539499] CoreText note: Client requested name "..SFCompactRounded-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.501 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactRounded-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.504 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactRounded-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.507 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactRounded-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.510 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactRounded-Thin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.513 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactRounded-Ultralight", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.516 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactRounded-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.520 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactRounded-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.523 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactRounded-Heavy", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.526 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactRounded-Black", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.530 system_profiler[20512:539499] CoreText note: Client requested name "..SFCompactText-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.533 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.536 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-RegularG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.539 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-RegularG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.543 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-RegularG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.546 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.549 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.553 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-Thin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.556 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-Ultralight", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.560 system_profiler[20512:539499] CoreText note: Client requested name "..SFCompactText-Italic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.564 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-RegularItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.567 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-RegularItalicG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.570 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-RegularItalicG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.573 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-RegularItalicG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.576 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-MediumItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.579 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-LightItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.583 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-ThinItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.586 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-UltralightItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.589 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.592 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.595 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-BoldG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.599 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-BoldG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.602 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-BoldG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.605 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-Heavy", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.608 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-SemiboldItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.612 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-BoldItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:43:59.615 system_profiler[20512:539499] CoreText note: Client requested name ".SFCompactText-BoldItalicG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# ...
# 2024-11-09 15:44:00.000 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSMono-HeavyItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.005 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.010 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-RegularG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.014 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-RegularG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.018 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-RegularG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.022 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-RegularG4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.026 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.030 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-MediumG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.034 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-MediumG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.038 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-MediumG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.042 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-MediumG4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.046 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.049 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-LightG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.053 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-LightG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.057 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-LightG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.061 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-LightG4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.065 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-Thin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.070 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-ThinG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.074 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-ThinG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.077 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-ThinG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.081 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-ThinG4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.086 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-Ultralight", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.089 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-UltralightG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.093 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-UltralightG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.097 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-UltralightG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.102 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-UltralightG4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.107 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-Ultrathin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.111 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.115 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-SemiboldG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.120 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-SemiboldG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.124 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-SemiboldG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.129 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-SemiboldG4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.133 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.138 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-BoldG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.142 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-BoldG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.146 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-BoldG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.149 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-BoldG4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.153 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-Heavy", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.157 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-HeavyG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.161 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-HeavyG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.165 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-HeavyG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.169 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-HeavyG4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.173 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-UltrathinG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.177 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-UltrathinG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.181 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-UltrathinG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.185 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-UltrathinG4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.190 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSRounded-Black", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.196 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSTextCondensed-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.201 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSTextCondensed-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.206 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSTextCondensed-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.211 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSTextCondensed-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.216 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSTextCondensed-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-11-09 15:44:00.220 system_profiler[20512:539499] CoreText note: Client requested name ".SFNSTextCondensed-Heavy", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].

# %% [markdown]
# Here, we will look at returns of the S&P 500 index. To that end, we first need to import price data for the S&P 500 from a csv data file. After doing that in code line 4, we print the head of the data set in code line 5 to see how the data set is structured. We have two columns: A 'Date' column and a 'price' column with the S&P 500's closing price for the respective date.

# %%
sp500 = pd.read_csv('sp500.csv', parse_dates = ['Date'])
sp500.head()
# Out:
#         Date    price
# 0 1999-12-31  1469.25
# 1 2000-01-03  1455.22
# 2 2000-01-04  1399.42
# 3 2000-01-05  1402.11
# 4 2000-01-06  1403.45

# %% [markdown]
# The first step is to compute log returns. Remember the formula for log returns:
#
# $$r_t = \log \left( \frac{S_t}{S_{t-1}} \right) = \log S_t - \log S_{t-1}.$$
#
# We use the numpy function 'log' to compute the natural logarithm of the observed prices. Also, we use pandas' 'shift' function to shift all prices forward by one period. That way, we can easily handle the one-period time lag between $S_t$ and $S_{t-1}$.

# %%
sp500['logret'] = np.log(sp500['price']) - np.log(sp500['price'].shift())

# %% [markdown]
# Having thus calculated daily log returns, we now plot their time series. Code lines 7 to 10 create that easy plot for us. As you can see, returns look very noisy over time: Days with positive and negative returns quickly follow each other. Also, their magnitude appears to be changing over time. Return look noisier during the financial crisis 2008-2009 than during the calm period between 2004-2006. Overall, the magnitudes appear realistic, with the largest one-day return around +10% and the smallest one-day return around -10%. This visual test is an important step in identifying data errors: If something does totally not fit to you intuition, it might be a flaw in the data.

# %%
plt.plot(sp500['Date'], sp500['logret'])
plt.xlabel("Date")
plt.ylabel("S&P500 Daily Log-Return")
plt.show()

# %% [markdown]
# We continue by computing the daily mean of log returns over time in code line 11. For that, we use the 'np.mean(...)' function. Afterward, we print the result. The average daily S&P 500 return is fairly low, in the order of 0.01% per day.

# %%
daily_return_mean = np.mean(sp500['logret'])
print("Daily Mean of Log-Returns: ", daily_return_mean)
# Out:
# Daily Mean of Log-Returns:  0.0001361246114135408

# %% [markdown]
# Next, we calculate the standard deviation of daily returns with the use of the 'np.std(...)' function in code line 13. Again we print the result afterwards. Compared to their average mean, returns have a high standard deviation of around 1.2% per day.

# %%
daily_return_std = np.std(sp500['logret'])
print("Daily Standard Deviation of Log-Returns: ", daily_return_std)
# Out:
# Daily Standard Deviation of Log-Returns:  0.011738696773211085

# %% [markdown]
# It is often easier for comparing the return characteristics of different assets to work with yearly numbers. To that end, we *annualize* our daily return statistics. Annualization just assumes that the same statistic (i.e. mean and standard deviation) applies to each return in a year. That way, we can easily calculate the yearly mean return as 252 time the daily mean return. Why 252? Well, there are on average 252 trading days in a year. Code line 15 does that. We can now easily see that the S&P 500 earned an average yearly return of 3.4% during our time frame. That number is much more intuitive and easier to handle than the daily figure.

# %%
annual_return_mean = daily_return_mean * 252
print("Annualized Mean of Log-Returns: ", annual_return_mean)
# Out:
# Annualized Mean of Log-Returns:  0.03430340207621228

# %% [markdown]
# We do the same for standard deviation. Remember that standard deviation scales with the root of the time period, though. This means, for annualizing our daily standard deviation figure, we need to multiply it with $\sqrt{252}$. We do that in code line 17. By using the root, the difference between the daily and the yearly figure is not as large as for the mean. Still, we see that the S&P 500 had an average yearly standard deviation of 18.6% during our sample period.

# %%
annual_return_std = daily_return_std * (252**0.5)
print("Annualized Standard Deviation of Log-Returns: ", annual_return_std)
# Out:
# Annualized Standard Deviation of Log-Returns:  0.18634603426747745

# %% [markdown]
# Finally, let's calculate a Sharpe ratio as a measure for the profitability of some investment. The Sharpe ratio is defined as the ratio of the premium above the riskfree rate, that an asset earns, and its volatility:
#
# $$SR = \frac{r - r_f}{\sigma_r}$$
#
# We will just use a riskfree rate of 1% here, which we define in code line 19. We follow the formula above in code line 20 and arrive at a Sharpe ratio of 0.13. This is lower than the long-term average for the S&P 500, which is around 0.4.

# %%
riskfree_rate = 0.01
Sharpe_ratio = (annual_return_mean - riskfree_rate) / annual_return_std
print("Yearly Sharpe Ratio for the S&P 500: ", Sharpe_ratio)
# Out:
# Yearly Sharpe Ratio for the S&P 500:  0.1304208172272003

# %% [markdown]
# MU: potential exercise
# 1. redo the calculation with simple returns and see whether any of the results are different
#
# 2. take the daily data and create a monthly time series of it. then, re-do the exercise, separately, for log and simple returns and see whether results differ.
