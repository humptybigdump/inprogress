# %%
organism = [
    "E. coli",
    "S. cerevisiae",
    "D. melanogaster",
    "H. sapiens",
    "M. musculus",
    "G. gallus"
]

#print(organism[0] , organism[ -2])
#print(len(organism))
#print(organism[1:3])
# Out:
# E. coli M. musculus
# 6
# ['S. cerevisiae', 'D. melanogaster']

# %%
organism_genome = [
    ["E. coli", "4.6 Mb"],
    ["S. cerevisiae", "12.1 Mb"],
    ["D. melanogaster", "139.5 Mb"],
    ["H. sapiens", "3.2 Gb"],
    ["M. musculus", "2.7 Gb"],
    ["G. gallus", "1.2 Gb"]
]

#print(organism_genome[0])
#print(organism_genome[2][0])
# Out:
# 4.6 Mb
# 12.1 Mb
# 139.5 Mb
# 3.2 Gb
# 2.7 Gb
# 1.2 Gb

# %%
matrix = [ [11, 12, 13], [21, 22, 23], [31, 32, 33] ]

# Outer loop: iterate over the 'rows'
for row in matrix:
    # Inner loop: iterate over the 'columns' of current 'row'
    for col in row:
        print(col, end = ' ')
    print()
# Out:
# 11  12  13
# 21  22  23
# 31  32  33

# %%
matrix_3d = [
    [# Front plane (which is a 2d matrix)
    [111, 112, 113], [121, 122, 123], [131, 132, 133]
    ],

    [ # Mid plane (which is a 2d matrix)
    [211, 212, 213], [221, 222, 223], [231, 232, 233]
    ],

    [ # Rear plane (which is a 2d matrix)
    [311, 312, 313], [321, 322, 323], [331, 332, 333]
    ]
]

# %%
genome_dict = {
    "E. coli": "4.6 Mb", "S. cerevisiae": "12.1 Mb", "D. melanogaster": "139.5 Mb",
    "H. sapiens": "3.2 Gb", "M. musculus": "2.7 Gb", "G. gallus": "1.2 Gb"
}

print( genome_dict["M. musculus"] )
# Out:
# 2.7 Gb

# %%
genome_dict["Rattus norvegicus"]

# %%
genome_dict["G. gallus"]
# Out:
# '1.2 Gb'

# %%
# adding new entries in a dictionary
genome_dict["R. norvegicus"] = "2.8 Gb"
print( genome_dict["R. norvegicus"] )

# altering existing entries in a dictionary
genome_dict["E. coli"] = "5.0 Gb"
print( genome_dict["E. coli"] )
# Out:
# 2.8 Gb
# 5.0 Gb
