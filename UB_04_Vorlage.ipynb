# %% [markdown]
# <h1> Technische Mechanik II - SS 2024</h1>
#
# <h2> Rechneraufgabe Übungsblatt 4 </h2>
#
# <h3> Institut für Technische Mechanik (Prof. Böhlke) </h3>
#
# <h4> Karlsruher Institut für Technologie (KIT) </h4>
#
# <b>Allgemeine Hinweise zur Bearbeitung von Rechnerhausaufgaben:</b>
#
# Alle verwendeten Einheiten sind <b>[N]</b> für Kräfte und <b>[mm]</b> (in dieser Aufgabe) für Längen. Abgeleitete Einheiten wie z.B. <b>[Nm]</b> ergeben sich aus den Definitionsgleichungen der jeweiligen Größen. Sofern nicht in der Aufgabenstellung gefordert, wird im Quellcode auf die explizite Verwendung von Einheiten verzichtet. Bei der Bearbeitung der Aufgabe ist dennoch kontinuierlich auf Konsistenz der Maßzahlen und Maßeinheiten zu achten. Halten Sie sich durchgehend an in der Aufgabenstellung vorgegebene Bezeichnungen und Koordinatensysteme. Falls im Code Namenskonventionen eingeführt werden, sind diese ebenfalls durchgängig einzuhalten.

# %% [markdown]
# # ![image.png](attachment:a0726369-5ef7-4d34-b3c4-3dd07f9064d0.png)

# %% [markdown]
# ## Teilaufgaben 1

# %%
import sympy as sympy
from IPython.display import display

# %% [markdown]
# ### ![image.png](attachment:59b5c976-71d5-4ee1-94f9-228c5fab4d1c.png)

# %% [markdown]
# ### ![image.png](attachment:1762a9e4-1c99-4bd5-9626-5acc7b2729d4.png)

# %%
import matplotlib.pyplot as matplotlib

# %% [markdown]
# ###    ![image.png](attachment:b2def808-90af-40cf-bd50-449735f69cc4.png)
#
# ![image.png](attachment:22ef16c6-dbc4-4971-aa48-f7a93e1c8981.png)

# %% [markdown]
# ### ![image.png](attachment:e50a7f8a-6aa5-489e-aa88-13db389af2d5.png)

# %% [markdown]
# ![image.png](attachment:297612b6-78bf-4978-87fe-ecc092f8b00f.png)

# %% [markdown]
# ### ![image.png](attachment:7a79091e-bc73-4897-b93e-80af9a39850a.png)

# %% [markdown]
# ![image.png](attachment:f7603294-03d7-45ac-9dc0-3f85354ec619.png)

# %% [markdown]
# ![image.png](attachment:af190602-3546-431a-8098-da178d35fe5b.png)

# %% [markdown]
# ## Teilaufgaben 2

# %% [markdown]
# ### ![image.png](attachment:060cbbd9-6410-474c-9f15-5fb8b1017696.png)

# %% [markdown]
# ### ![image.png](attachment:40d68e2e-4e3d-4248-be00-5064985b5cfe.png)

# %% [markdown]
# ### ![image.png](attachment:ab428e51-48b6-4dde-be87-c0dca11cb94b.png)

# %% [markdown]
# ### ![image.png](attachment:a3dac348-e4c1-4830-ac5d-64394b573ebb.png)

# %% [markdown]
# Hinweis: Verwenden Sie $sympy.limit()$

# %% [markdown]
# ## ![image.png](attachment:42cc6355-7804-4218-8883-5a6b9c72ae9c.png)
#
# ![image.png](attachment:2a861733-284e-4c3b-b0bc-173bb89e810b.png)

# %% [markdown]
# ## ![image.png](attachment:a63364f4-f9b5-4dab-ba97-17c515e4d77d.png)

# %% [markdown]
# ## ![image.png](attachment:af488635-0d62-442a-ba4e-e22d4ccb4440.png)

# %% [markdown]
# ## ![image.png](attachment:5645cdc1-8b38-412d-a571-9d3ab151387b.png)

# %% [markdown]
# ## ![image.png](attachment:1a590a13-c316-4b5d-b26c-e8f110c0188e.png)

# %% [markdown]
# ## ![image.png](attachment:5046acff-be4a-4370-8036-3fab306c7b8c.png)

# %% [markdown]
# $$ \rho = 2.7 \frac{g}{cm^3}, \ l = 1.1m, \ h = 0.005m, \ m = 1kg, \ S = 3, \ M_{T0} = 200Nm, \ \tau_c = 170MPa$$ <br>
#
# geg: $l, \ h, \, \rho, \ \tau_c, \ m, \ M_{T0} , \ S$

# %% [markdown]
# ## ![image.png](attachment:4bf95f31-5eb5-4790-a270-ad5877f2ef95.png)
