# %% [markdown]
# # Python Basics — Definitions and Data Types
#
# ---

# %% [markdown]
# ## 1.1 Introduction to Variables and Assignment
#
# In Python, a **variable** is used to store information such as numbers, text, or more complex data.
#
# You assign a value to a variable using the `=` symbol. Python is dynamically typed, so you don't need to declare the type explicitly.
#
# **Example**:
# ```python
# mass = 70  # mass in kilograms
# material = "Steel"  # material name
# ```
#
# Variable names should be descriptive and use lowercase letters with underscores (`_`) to separate words (by convention).

# %%
# Assign a value for density of water in kg/m^3
density = 

# Assign a string representing the material name (e.g., "Aluminum")
material =

# %% [markdown]
# ## 1.2 Basic Data Types
#
# Python has several basic types:
#
# | Type | Example | Description |
# |:----|:--------|:------------|
# | `int` | `5` | Integer number |
# | `float` | `3.14` | Decimal number |
# | `str` | `"Steel"` | Text (string) |
# | `bool` | `True`, `False` | Logical values |
#
# You can check the type of a variable using the `type()` function:
# ```python
# type(5)  # Returns <class 'int'>
# ```

# %%
# Define an integer for the number of gears
num_gears = 

# Define a float for the temperature in Celsius
temperature_celsius = 

# Define a boolean for whether a system is active
system_active = 

# Check the types
print(type(num_gears))
print(type(temperature_celsius))
print(type(system_active))

# %% [markdown]
# ## 1.3 Collections: Lists
#
# A **list** stores multiple items in a single variable. Lists are ordered, changeable (mutable), and allow duplicate values.
#
# Lists are created using square brackets `[]`:
# ```python
# materials = ["Steel", "Aluminum", "Copper"]
# ```
#
# You can access list items by their index (starting from 0):
# ```python
# print(materials[0])  # Output: Steel
# ```

# %%
# Create a list of 3 mechanical materials
materials = 

# Print the second material in the list
print()

# %% [markdown]
# ## 1.4 Collections: Tuples
#
# A **tuple** is similar to a list, but it is **immutable** (cannot be changed after creation).
#
# Useful for fixed sets of items.
#
# Tuples are created using parentheses `()`:
# ```python
# dimensions = (2.0, 4.5, 7.0)  # length, width, height
# ```

# %%
# Create a tuple representing (length, width, height) of a beam in meters
beam_dimensions = 

# Print the tuple
print(beam_dimensions)

# %% [markdown]
# ## 1.5 Collections: Dictionaries
#
# A **dictionary** stores data as key-value pairs.
#
# Keys are unique identifiers, and values are the associated data.
#
# Dictionaries are created using curly braces `{}`:
# ```python
# material_density = {
#     "Steel": 7850,
#     "Aluminum": 2700,
#     "Copper": 8960
# }
# ```
#
# You can access values by using keys:
# ```python
# print(material_density["Steel"])  # Output: 7850
# ```

# %%
# Create a dictionary mapping 3 metals to their densities (kg/m^3)
metal_densities = 

# Retrieve and print the density of Aluminum
print()

# %% [markdown]
# ## Practical Exercise: Material Properties
#
# **Exercise:**
#
# 1. Create a dictionary named `youngs_modulus` that maps three metals (`Steel`, `Aluminum`, `Copper`) to their Young’s modulus values in GPa:
#    - Steel: 200 GPa
#    - Aluminum: 69 GPa
#    - Copper: 110 GPa
#
# 2. Print the Young's modulus of Copper.
#
# **Try it below!**

# %%
# Your code here
youngs_modulus = 

# Print the Young's modulus for Copper
print()

# %% [markdown]
# # Summary
#
# In this notebook, you learned:
# - How to assign variables in Python
# - The basic data types: int, float, string, bool
# - How to create and use lists, tuples, and dictionaries
#
# Remember: Lists are mutable, tuples are immutable, and dictionaries link keys to values.
