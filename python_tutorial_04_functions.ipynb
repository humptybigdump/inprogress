# %% [markdown]
# # Functions in Python
#
# ---

# %% [markdown]
# ## 4.1 What is a Function?
#
# A function is a reusable block of code that performs a specific task.
#
# Functions help:
# - Organize code
# - Avoid repetition
# - Improve readability
# - Enable modular programming
#
# In Python, a function is defined using the `def` keyword:
#
# ```python
# def function_name(parameters):
#     statements
#     return result
# ```

# %%
# Define a simple function that returns the square of a number

# Example usage:
# result = square(4)
# print(result)  # Output should be 16

# %% [markdown]
# ## 4.2 Function Arguments
#
# Functions can have:
# - Required arguments
# - Default arguments
# - Variable-length arguments
#
# Example with a default argument:
#
# ```python
# def greet(name="Engineer"):
#     print(f"Hello, {name}!")
# ```
#
# If no name is provided, it defaults to "Engineer".

# %%
# Define a function that computes the area of a rectangle
# If no height is provided, assume it is a square (height = width)

# Example usage:
# area1 = area_rectangle(5, 10)  # Rectangle
# area2 = area_rectangle(4)      # Square

# %% [markdown]
# ## 4.3 Return Values
#
# Functions can return results using the `return` statement.
#
# You can return multiple values as a tuple.

# %%
# Define a function that takes a force and area, and returns both pressure and stress
# Pressure = Force / Area
# Assume stress = Force / Area as well in simple cases

# Example usage:
# pressure, stress = calculate_pressure_stress(100, 20)
# print(pressure, stress)

# %% [markdown]
# ## 4.4 Scope of Variables
#
# Variables defined inside a function are **local** to that function.
#
# They are not accessible outside the function unless returned.

# %%
# Example: define a function that sets a variable inside
# Try to access the variable outside the function and observe the result

def local_example():
    internal_value = 42
    print("Internal value:", internal_value)

# Call the function
local_example()

# Try to print internal_value here

# %% [markdown]
# ## 4.5 Lambda Functions (Anonymous Functions)
#
# Lambda functions are small, anonymous functions defined with the `lambda` keyword.
#
# They are useful for short operations that are not reused.
#
# Example:
#
# ```python
# square = lambda x: x ** 2
# print(square(5))
# ```

# %%
# Define a lambda function that calculates kinetic energy
# Kinetic energy = (1/2) * mass * velocity^2

# Example usage:
# ke = kinetic_energy(5, 3)
# print(ke)

# %% [markdown]
# ## Practical Exercise: Beam Deflection Calculator
#
# Write a function to calculate the maximum deflection `w_max` for a simply supported beam under a uniform load.
#
# Use the formula:
#
# $ w_{max} = \frac{5wL^4}{384EI} $
#
# Where:
# - `w`: load per unit length (N/m)
# - `L`: length of beam (m)
# - `E`: modulus of elasticity (Pa)
# - `I`: second moment of area (m⁴)
#
# Inputs should be `w`, `L`, `E`, `I`.
# Return the calculated deflection.

# %%
# Your code here

def calculate_deflection(w, L, E, I):
    pass  # Replace with your implementation

# Example usage:
# delta = calculate_deflection(500, 5, 200e9, 8.333e-6)
# print(f"Maximum deflection: {delta} meters")

# %% [markdown]
# # Summary
#
# In this notebook, you learned:
# - How to define and call functions
# - How to use arguments and return values
# - About variable scope
# - How to create lambda (anonymous) functions
#
# Functions are crucial for writing organized, maintainable, and efficient engineering code.
