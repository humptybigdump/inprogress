# %% [markdown]
# # Introduction to Pandas
#
# ---

# %% [markdown]
# ## 6.1 What is Pandas?
#
# Pandas is a Python library for working with structured data.
#
# It provides two main data structures:
# - `Series`: a one-dimensional labeled array
# - `DataFrame`: a two-dimensional labeled table
#
# Pandas is widely used for data cleaning, analysis, and manipulation in engineering and research.
#
# We import it conventionally as:
#
# ```python
# import pandas as pd
# ```

# %%
# Import pandas as pd

# %% [markdown]
# ## 6.2 Creating a Series
#
# A `Series` is like a column in a table. It has:
# - Data values
# - An associated index (labels)
#
# Example:
#
# ```python
# s = pd.Series([10, 20, 30, 40])
# ```

# %%
# Create a Series representing the forces (in N) applied on five different beams
# Values: 100, 150, 200, 250, 300

# %% [markdown]
# ## 6.3 Creating a DataFrame
#
# A `DataFrame` is a two-dimensional table with rows and columns.
#
# Example:
#
# ```python
# data = {
#     'Force (N)': [100, 150, 200],
#     'Area (m²)': [0.01, 0.015, 0.02]
# }
# df = pd.DataFrame(data)
# ```
#
# Each column can have a different data type.

# %%
# Create a DataFrame for three materials with the following data:
# Material names: 'Steel', 'Aluminum', 'Copper'
# Densities (kg/m³): 7850, 2700, 8960
# Young's modulus (GPa): 200, 70, 110

# %% [markdown]
# ## 6.4 Accessing Data
#
# You can access columns and rows:
# - `df['column_name']`: Access a column
# - `df.loc[row_label]`: Access by label
# - `df.iloc[row_index]`: Access by position
#
# Example:
#
# ```python
# df['Force (N)']
# df.iloc[0]
# ```

# %%
# Access the 'Density' column of the materials DataFrame
# Access the first row of the DataFrame

# %% [markdown]
# ## 6.5 Basic DataFrame Operations
#
# You can:
# - Add new columns
# - Modify existing data
# - Apply mathematical operations column-wise
#
# Example:
#
# ```python
# df['Stress (Pa)'] = df['Force (N)'] / df['Area (m²)']
# ```

# %%
# Add a new column to the materials DataFrame calculating mass per unit volume (Density * 1 m³)
# Mass = Density * Volume (Volume = 1 m³ for simplicity)

# %% [markdown]
# ## 6.6 Filtering Data
#
# You can filter rows based on a condition:
#
# ```python
# df[df['Density'] > 5000]
# ```
#
# This returns all rows where the density is greater than 5000 kg/m³.

# %%
# Filter the materials DataFrame to select materials with Young's modulus greater than 100 GPa

# %% [markdown]
# ## 6.7 Summary Functions
#
# Pandas provides easy ways to summarize your data:
# - `df.describe()`: Basic statistics
# - `df.mean()`, `df.median()`, `df.std()`: Specific statistics
# - `df.info()`: Data types and memory usage

# %%
# Use describe() to generate summary statistics for the materials DataFrame

# %% [markdown]
# ## Practical Exercise: Engineering Test Results
#
# You are given the following test results for three samples:
#
# - Sample IDs: 'A1', 'A2', 'A3'
# - Ultimate strength (MPa): 450, 470, 490
# - Yield strength (MPa): 300, 320, 340
# - Elongation (%): 20, 22, 21
#
# Tasks:
# - Create a DataFrame.
# - Add a new column calculating the safety factor (Ultimate strength / Yield strength).
# - Find the sample with the highest elongation.

# %%
# Your code here

# %% [markdown]
# # Summary
#
# In this notebook, you learned:
# - How to create and manipulate Series and DataFrames
# - How to access, filter, and modify data
# - How to perform simple statistical analysis on structured engineering data
#
# Pandas is an essential tool for handling real-world mechanical engineering datasets efficiently.
