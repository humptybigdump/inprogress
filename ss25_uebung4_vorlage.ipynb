# %%
import pandas

# %%
data = pandas.read_excel("data.xlsx")
data
# Out:
#            x         y
# 0   8.704628  4.623982
# 1   7.218730  2.282839
# 2   9.103622  3.886074
# 3   3.998943  1.628829
# 4   8.902633  4.664581
# ..       ...       ...
# 60  3.047710  2.461968
# 61  3.083300  5.816858
# 62  3.315759  3.296532
# 63  0.972998  2.193255
# 64  8.945055  2.648436
#
# [65 rows x 2 columns]
